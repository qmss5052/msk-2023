# %%
# Read Gene Data
# read the gene text file, "all_sample, z_scores"
# what's the difference between gene all sample dataset and gene relative to diploid samples? 
import pandas as pd
df_all = pd.read_csv("data_mrna_seq_v2_rsem_zscores_ref_all_samples.txt", sep="\t")
df_diploid = pd.read_csv("data_mrna_seq_v2_rsem_zscores_ref_diploid_samples.txt", sep="\t")

# %%
# this is the gene name corresponding to the gene Id, while some gene might do not have gene symbol 
gene_symbol_id = df_all.iloc[:,:2].copy()
gene_symbol_id.tail(3)
# Out:
#       Hugo_Symbol  Entrez_Gene_Id
# 20528         ZYX            7791
# 20529       ZZEF1           23140
# 20530        ZZZ3           26009

# %%
df_all_clean = df_all.set_index("Entrez_Gene_Id").drop("Hugo_Symbol", axis = 1).transpose()
df_all_clean
# Out:
# Entrez_Gene_Id   100130426  100133144  100134869  10357      10431      \
# TCGA-CS-4938-01    -6.6197     0.1185     0.8030     1.9096     1.1627
# TCGA-CS-4941-01    -6.6197     2.0342     0.6853     0.2687    -1.7875
# TCGA-CS-4942-01    -6.6197     0.5116    -0.3650     0.7763    -0.0135
# TCGA-CS-4943-01    -6.6197     0.1034    -1.5341     1.9239     1.1169
# TCGA-CS-4944-01    -6.6197    -3.1094     1.2744     1.2506     1.0094
# ...                    ...        ...        ...        ...        ...
# TCGA-WY-A85A-01    -6.6197    -0.4623     0.2481    -0.4197     0.2058
# TCGA-WY-A85B-01    -6.6197     0.0507     0.5676    -0.2125     0.2314
# TCGA-WY-A85C-01    -6.6197     0.4778     0.4846    -0.5183    -0.6588
# TCGA-WY-A85D-01    -6.6197    -0.4763    -0.6968    -0.8822     0.4685
# TCGA-WY-A85E-01    -6.6197     0.2876    -0.9707    -0.0090     0.6967
#
# Entrez_Gene_Id   136542     155060     26823      280660     317712     ...  \
# ...

# %%
df_diploid_clean = df_diploid.set_index("Entrez_Gene_Id").drop("Hugo_Symbol", axis = 1).transpose()
df_diploid_clean
# Out:
# Entrez_Gene_Id   100134869  10357      155060     26823      280660     \
# TCGA-CS-4938-01     0.6030        NaN    -0.7953        NaN    -0.0717
# TCGA-CS-4941-01     0.4441        NaN    -0.3710        NaN    -0.0717
# TCGA-CS-4942-01    -0.5791        NaN    -0.9481        NaN    -0.0717
# TCGA-CS-4943-01    -1.1779        NaN    -1.0900        NaN    -0.0717
# TCGA-CS-4944-01     1.3598        NaN    -1.0983        NaN    -0.0717
# ...                    ...        ...        ...        ...        ...
# TCGA-WY-A85A-01    -0.0586        NaN     0.2702        NaN    -0.0717
# TCGA-WY-A85B-01     0.2961        NaN     0.4774        NaN    -0.0717
# TCGA-WY-A85C-01     0.1974        NaN     1.1548        NaN    -0.0717
# TCGA-WY-A85D-01    -0.7922        NaN     1.0595        NaN    -0.0717
# TCGA-WY-A85E-01    -0.9396        NaN     2.2160        NaN    -0.0717
#
# Entrez_Gene_Id   340602     388795     390284     391343     391714     ...  \
# ...

# %%
# Read Clinic Data

df_clinic_sample = pd.read_csv("data_clinical_sample.txt", sep="\t")
df_clinic_sample
# questions: 
# 1) what is subtypes? 
# 2）what is mutation vs Genome Altered?
# Out:
#                             #Patient Identifier            Sample Identifier  \
# 0    #Identifier to uniquely specify a patient.  A unique sample identifier.
# 1                                       #STRING                       STRING
# 2                                            #1                            1
# 3                                    PATIENT_ID                    SAMPLE_ID
# 4                                  TCGA-CS-4938              TCGA-CS-4938-01
# ..                                          ...                          ...
# 513                                TCGA-WY-A85B              TCGA-WY-A85B-01
# 514                                TCGA-WY-A85C              TCGA-WY-A85C-01
# 515                                TCGA-WY-A85D              TCGA-WY-A85D-01
# 516                                TCGA-WY-A85E              TCGA-WY-A85E-01
# 517                                TCGA-R8-A6YH              TCGA-R8-A6YH-01
#
# ...

# %%
df_clinic_patient = pd.read_csv("data_clinical_patient.txt", sep="\t")
df_clinic_patient
# Out:
#                             #Patient Identifier               Subtype  \
# 0    #Identifier to uniquely specify a patient.               Subtype
# 1                                       #STRING                STRING
# 2                                            #1                     1
# 3                                    PATIENT_ID               SUBTYPE
# 4                                  TCGA-CS-4938  LGG_IDHmut-non-codel
# ..                                          ...                   ...
# 513                                TCGA-WY-A85B  LGG_IDHmut-non-codel
# 514                                TCGA-WY-A85C  LGG_IDHmut-non-codel
# 515                                TCGA-WY-A85D  LGG_IDHmut-non-codel
# 516                                TCGA-WY-A85E  LGG_IDHmut-non-codel
# 517                                TCGA-R8-A6YH  LGG_IDHmut-non-codel
#
#                   TCGA PanCanAtlas Cancer Type Acronym  \
# 0    Text field to hold cancer type acronym used by...
# ...
