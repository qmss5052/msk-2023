# %% [markdown]
# ## Basic Information (Brain Lower Grade Glioma)
#
# Siqi Liu

# %%
import numpy as np 
import pandas as pd 
import scanpy as sc 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

sc.settings.verbosity = 3 

sc.settings.set_figure_params(dpi = 80)
# %matplotlib inline

# %% [markdown]
# ## Gene Data

# %%
# read the gene expression data: 
raw_data_rna = pd.read_table("./data/data_mrna_seq_v2_rsem.txt", sep="\t")
raw_data_rna.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-CS-4938-01  TCGA-CS-4941-01  \
# 0         NaN       100130426           0.0000           0.0000
# 1         NaN       100133144           8.7141          36.4493
# 2    UBE2Q2P2       100134869          22.7523          21.1767
# 3     HMGB1P1           10357         268.5760         156.6870
# 4         NaN           10431         845.8150         390.2690
#
#    TCGA-CS-4942-01  TCGA-CS-4943-01  TCGA-CS-4944-01  TCGA-CS-5390-01  \
# 0           0.0000           0.0000            0.000           0.0000
# 1          11.8131           8.6116            0.000           5.3382
# 2          11.0242           5.0835           30.261          27.8886
# 3         185.1380         269.8360          216.341         159.7590
# 4         621.4530         835.7290          812.508         576.9050
#
#    TCGA-CS-5393-01  TCGA-CS-5394-01  ...  TCGA-VW-A8FI-01  TCGA-W9-A837-01  \
# 0           0.0000           0.0000  ...           0.0000           0.0000
# 1           3.7845           8.3071  ...          19.1299          12.5770
# 2           8.7230          15.4466  ...          21.9905          27.0125
# 3         198.1880         208.5410  ...         127.7470         106.8290
# 4         551.9470         607.8960  ...         564.3620         603.3720
#
#    TCGA-WH-A86K-01  TCGA-WY-A858-01  TCGA-WY-A859-01  TCGA-WY-A85A-01  \
# 0           0.0000           0.0000           0.0000           0.0000
# 1          10.9796           7.8225           3.3371           5.4526
# 2          14.2608          16.6975          10.2310          16.1890
# 3         205.5170         184.4080         125.5470         124.9190
# 4         570.9130         760.7160         875.1410         658.2210
#
#    TCGA-WY-A85B-01  TCGA-WY-A85C-01  TCGA-WY-A85D-01  TCGA-WY-A85E-01
# 0           0.0000           0.0000           0.0000           0.0000
# 1           8.2616          11.5121           5.3895           9.9433
# 2          19.7074          18.7291           8.9103           7.4480
# 3         133.7390         120.9240         107.2540         143.0060
# 4         662.6510         524.7240         705.1280         748.5820
#
# [5 rows x 516 columns]

# %%
# choosing Entrez_Gene_Id as column because: 
print(f"There are {len(raw_data_rna[raw_data_rna.Entrez_Gene_Id.isna()])} genes has no ids")
print("we would use Entrez_Gene_Id as name of gene with a correponding dictionary table")
gene_symbol_id = raw_data_rna.iloc[:,:2].copy()
gene_symbol_id.tail()
# Out:
# There are 0 genes has no ids
# we would use Entrez_Gene_Id as name of gene with a correponding dictionary table
#       Hugo_Symbol  Entrez_Gene_Id
# 20526      ZYG11A          440590
# 20527      ZYG11B           79699
# 20528         ZYX            7791
# 20529       ZZEF1           23140
# 20530        ZZZ3           26009

# %%
# 
gene_symbol_id[gene_symbol_id.Entrez_Gene_Id == 3122]
# Out:
#      Hugo_Symbol  Entrez_Gene_Id
# 7912     HLA-DRA            3122

# %%
# transpose the data and make the gene id as the column names: 
df_clean = raw_data_rna.set_index("Entrez_Gene_Id").drop("Hugo_Symbol", axis = 1).transpose()
print(f"There are {len(df_clean)} samples in total, and there are {len(df_clean.columns)} genes in total.")
df_clean.head()
# Out:
# There are 514 samples in total, and there are 20531 genes in total.
# Entrez_Gene_Id   100130426  100133144  100134869  10357      10431      \
# TCGA-CS-4938-01        0.0     8.7141    22.7523    268.576    845.815
# TCGA-CS-4941-01        0.0    36.4493    21.1767    156.687    390.269
# TCGA-CS-4942-01        0.0    11.8131    11.0242    185.138    621.453
# TCGA-CS-4943-01        0.0     8.6116     5.0835    269.836    835.729
# TCGA-CS-4944-01        0.0     0.0000    30.2610    216.341    812.508
#
# Entrez_Gene_Id   136542     155060     26823      280660     317712     ...  \
# TCGA-CS-4938-01        0.0    182.505     0.4196        0.0        0.0  ...
# TCGA-CS-4941-01        0.0    325.052     1.7253        0.0        0.0  ...
# TCGA-CS-4942-01        0.0    131.142     0.0000        0.0        0.0  ...
# TCGA-CS-4943-01        0.0     83.475     0.3261        0.0        0.0  ...
# TCGA-CS-4944-01        0.0     80.696     0.0000        0.0        0.0  ...
#
# Entrez_Gene_Id   55055      11130      7789       158586     79364      \
# TCGA-CS-4938-01    80.1636    50.3461    64.1913    523.180    1311.52
# TCGA-CS-4941-01   187.2980   110.4210   105.9350    467.564    1226.71
# TCGA-CS-4942-01   120.0310   186.5050   115.2250    454.325    1102.42
# TCGA-CS-4943-01   667.4480  1183.6500    89.0183    491.068    1288.32
# TCGA-CS-4944-01    57.3244    56.4872    42.3654    323.793    1012.73
#
# Entrez_Gene_Id   440590     79699      7791       23140      26009
# TCGA-CS-4938-01     0.0000    1495.70    1598.91   1171.810    836.165
# TCGA-CS-4941-01     0.3451    1751.21    3889.92   1707.730   1015.530
# TCGA-CS-4942-01     0.3460    1586.16    2214.53   1423.880    706.920
# TCGA-CS-4943-01     3.2607    1760.15    2131.55   1916.990    689.321
# TCGA-CS-4944-01     0.5044    1225.07    1692.60    729.794    456.941
#
# [5 rows x 20531 columns]

# %%
# check the quality of the data: 
# 1) if there is any NA data
print(f"If there is NA values: {df_clean.isnull().values.any()}")

# 2) if there are columns with all the same value
unique_counts = df_clean.nunique()
same_value_cols = unique_counts[unique_counts == 1].index.tolist()
print(f"There are {len(same_value_cols)} columns with the same value.")
print(f"{same_value_cols[0:10]}...")
# Out:
# If there is NA values: False
# There are 307 columns with the same value.
# [136542, 317712, 728045, 728036, 255313, 728096, 728062, 653282, 728042, 57135]...

# %%
# thus, we need to drop all of same_value_cols: 
df_clean_1 = df_clean.drop(same_value_cols, axis = 1)
df_clean_1.head()
# Out:
# Entrez_Gene_Id   100130426  100133144  100134869  10357      10431      \
# TCGA-CS-4938-01        0.0     8.7141    22.7523    268.576    845.815
# TCGA-CS-4941-01        0.0    36.4493    21.1767    156.687    390.269
# TCGA-CS-4942-01        0.0    11.8131    11.0242    185.138    621.453
# TCGA-CS-4943-01        0.0     8.6116     5.0835    269.836    835.729
# TCGA-CS-4944-01        0.0     0.0000    30.2610    216.341    812.508
#
# Entrez_Gene_Id   155060     26823      280660     340602     388795     ...  \
# TCGA-CS-4938-01    182.505     0.4196        0.0     2.0978     0.4196  ...
# TCGA-CS-4941-01    325.052     1.7253        0.0     3.4507     0.3451  ...
# TCGA-CS-4942-01    131.142     0.0000        0.0     1.7301     0.3460  ...
# TCGA-CS-4943-01     83.475     0.3261        0.0     1.3043     0.0000  ...
# TCGA-CS-4944-01     80.696     0.0000        0.0     3.0261     0.0000  ...
#
# Entrez_Gene_Id   55055      11130      7789       158586     79364      \
# TCGA-CS-4938-01    80.1636    50.3461    64.1913    523.180    1311.52
# TCGA-CS-4941-01   187.2980   110.4210   105.9350    467.564    1226.71
# TCGA-CS-4942-01   120.0310   186.5050   115.2250    454.325    1102.42
# TCGA-CS-4943-01   667.4480  1183.6500    89.0183    491.068    1288.32
# TCGA-CS-4944-01    57.3244    56.4872    42.3654    323.793    1012.73
#
# Entrez_Gene_Id   440590     79699      7791       23140      26009
# TCGA-CS-4938-01     0.0000    1495.70    1598.91   1171.810    836.165
# TCGA-CS-4941-01     0.3451    1751.21    3889.92   1707.730   1015.530
# TCGA-CS-4942-01     0.3460    1586.16    2214.53   1423.880    706.920
# TCGA-CS-4943-01     3.2607    1760.15    2131.55   1916.990    689.321
# TCGA-CS-4944-01     0.5044    1225.07    1692.60    729.794    456.941
#
# [5 rows x 20224 columns]

# %%
df_clean_1.index
# Out:
# Index(['TCGA-CS-4938-01', 'TCGA-CS-4941-01', 'TCGA-CS-4942-01',
#        'TCGA-CS-4943-01', 'TCGA-CS-4944-01', 'TCGA-CS-5390-01',
#        'TCGA-CS-5393-01', 'TCGA-CS-5394-01', 'TCGA-CS-5395-01',
#        'TCGA-CS-5396-01',
#        ...
#        'TCGA-VW-A8FI-01', 'TCGA-W9-A837-01', 'TCGA-WH-A86K-01',
#        'TCGA-WY-A858-01', 'TCGA-WY-A859-01', 'TCGA-WY-A85A-01',
#        'TCGA-WY-A85B-01', 'TCGA-WY-A85C-01', 'TCGA-WY-A85D-01',
#        'TCGA-WY-A85E-01'],
#       dtype='object', length=514)

# %%
adata_gene = sc.AnnData(df_clean_1)

# %%
adata_gene
# Out:
# AnnData object with n_obs × n_vars = 514 × 20224

# %%
adata_gene.n_obs
# Out:
# 514

# %%
adata_gene.var_names
# Out:
# Index(['100130426', '100133144', '100134869', '10357', '10431', '155060',
#        '26823', '280660', '340602', '388795',
#        ...
#        '55055', '11130', '7789', '158586', '79364', '440590', '79699', '7791',
#        '23140', '26009'],
#       dtype='object', name='Entrez_Gene_Id', length=20224)

# %%
sc.pl.highest_expr_genes(adata_gene, n_top=20, )
#Show those genes that yield the highest fraction of counts in each single cell, across all cells.
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
# filter cell outliers based on counts and numbers of genes expressed 
# sc.pp.filter_cells(adata_gene, min_genes=200)
# sc.pp.filter_genes(adata_gene, min_cells = 3)
# Out:
# filtered out 114 genes that are detected in less than 3 cells

# %%
sc.tl.pca(adata_gene, svd_solver='arpack')
sc.pp.neighbors(adata_gene, n_neighbors=30, n_pcs=50)
sc.tl.umap(adata_gene, min_dist=0.3)
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:22)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
sc.pl.umap(adata_gene)

# %% [markdown]
# ## Mutation Data

# %%
raw_data_mutation = pd.read_table("../data/data_mutations.txt", sep="\t")
raw_data_mutation
# Out:
#       Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 0           CELF6         60677.0      .     GRCh37         15
# 1          GPR114             0.0      .     GRCh37         16
# 2            TP53          7157.0      .     GRCh37         17
# 3           KLK10          5655.0      .     GRCh37         19
# 4              C3           718.0      .     GRCh37         19
# ...           ...             ...    ...        ...        ...
# 39294       CABP5         56344.0      .     GRCh37         19
# 39295   HIST1H2BD             0.0      .     GRCh37          6
# 39296       HOXA2          3199.0      .     GRCh37          7
# 39297       PLIN2           123.0      .     GRCh37          9
# 39298        AQP3           360.0      .     GRCh37          9
#
#        Start_Position  End_Position Strand          Consequence  \
# 0            72608207      72608207      +   synonymous_variant
# 1            57601804      57601804      +     missense_variant
# 2             7577539       7577539      +     missense_variant
# 3            51518742      51518742      +   synonymous_variant
# 4             6686853       6686853      +          stop_gained
# ...               ...           ...    ...                  ...
# 39294        48533797      48533797      +  3_prime_UTR_variant
# 39295        26158800      26158800      +       intron_variant
# 39296        27140265      27140265      +  3_prime_UTR_variant
# 39297        19116192      19116192      +  3_prime_UTR_variant
# 39298        33442015      33442015      +  3_prime_UTR_variant
#
#       Variant_Classification  ... SYMBOL_SOURCE  \
# 0                     Silent  ...          HGNC
# 1          Missense_Mutation  ...          HGNC
# 2          Missense_Mutation  ...          HGNC
# 3                     Silent  ...          HGNC
# 4          Nonsense_Mutation  ...          HGNC
# ...                      ...  ...           ...
# 39294                  3'UTR  ...          HGNC
# 39295                 Intron  ...          HGNC
# 39296                  3'UTR  ...          HGNC
# 39297                  3'UTR  ...          HGNC
# 39298                  3'UTR  ...          HGNC
#
#                                                   TREMBL TSL        UNIPARC  \
# 0                                           B3KWE6_HUMAN   .  UPI000006F0AA
# 1                                                      .   .  UPI0000039944
# 2      S5LQU8_HUMAN,Q761V2_HUMAN,Q6IT77_HUMAN,Q1HGV1_...   .  UPI000002ED67
# 3                                           M0R132_HUMAN   .  UPI000013CCB0
# 4                              Q6LDJ0_HUMAN,M0R1Q1_HUMAN   .  UPI000013EC9B
# ...                                                  ...  ..            ...
# 39294                                                  .   .  UPI0000126D6A
# 39295                                                  .   .  UPI0000001BD3
# 39296                                                  .   .  UPI0000049C49
# 39297             Q6FHZ7_HUMAN,Q5SYF5_HUMAN,B4DJK9_HUMAN   .  UPI0000125535
# 39298                                                  .   .  UPI0000125D1C
#
#       VARIANT_CLASS                                        all_effects  \
# 0               SNV  CELF6,synonymous_variant,p.%3D,ENST00000567083...
# 1               SNV  GPR114,missense_variant,p.Asn286Lys,ENST000003...
# 2               SNV  TP53,missense_variant,p.Arg248Trp,ENST00000413...
# 3               SNV  KLK10,synonymous_variant,p.%3D,ENST00000391805...
# 4               SNV  C3,stop_gained,p.Gln49Ter,ENST00000601008,;C3,...
# ...             ...                                                ...
# 39294           SNV       CABP5,3_prime_UTR_variant,,ENST00000293255,;
# 39295           SNV  HIST1H2BD,3_prime_UTR_variant,,ENST00000377777...
# 39296           SNV  HOXA2,3_prime_UTR_variant,,ENST00000222718,;HO...
# 39297           SNV  PLIN2,3_prime_UTR_variant,,ENST00000276914,;PL...
# 39298           SNV  AQP3,3_prime_UTR_variant,,ENST00000297991,;AQP...
#
#       cDNA_position n_depth t_depth Annotation_Status
# 0               579      17      18           SUCCESS
# 1              1381      43      47           SUCCESS
# 2               932     117     102           SUCCESS
# 3               828     363     364           SUCCESS
# 4              3643     163     144           SUCCESS
# ...             ...     ...     ...               ...
# 39294           670      42      81           SUCCESS
# 39295             .      40      60           SUCCESS
# 39296          1522      25      40           SUCCESS
# 39297          1548      42      38           SUCCESS
# 39298           986     158     186           SUCCESS
#
# [39299 rows x 114 columns]

# %%
raw_data_mutation.groupby('Tumor_Sample_Barcode').Tumor_Sample_Barcode.count()
# Out:
# Tumor_Sample_Barcode
# TCGA-CS-4938-01    23
# TCGA-CS-4941-01    60
# TCGA-CS-4942-01    38
# TCGA-CS-4943-01    39
# TCGA-CS-4944-01    24
#                    ..
# TCGA-WY-A85A-01    19
# TCGA-WY-A85B-01    19
# TCGA-WY-A85C-01    38
# TCGA-WY-A85D-01    48
# TCGA-WY-A85E-01    84
# Name: Tumor_Sample_Barcode, Length: 510, dtype: int64

# %%
import matplotlib.pyplot as plt
gene_names = raw_data_mutation.groupby('Hugo_Symbol').Hugo_Symbol.count().index
mutated_gene = raw_data_mutation.groupby('Hugo_Symbol').Hugo_Symbol.count()
# plt.barh(range(len(mutated_gene)),mutated_gene)
mutated_gene_sort = raw_data_mutation.groupby('Hugo_Symbol').count().sort_values(by = "Entrez_Gene_Id", ascending=False).Entrez_Gene_Id

# %%
mutated_gene_sort
# Out:
# Hugo_Symbol
# IDH1      395
# TP53      320
# ATRX      226
# TTN       162
# CIC       131
#          ...
# MCOLN2      1
# MCMDC2      1
# MCMBP       1
# snoU13      1
# AKAP2       0
# Name: Entrez_Gene_Id, Length: 13917, dtype: int64

# %%
raw_data_mutation.iloc[0,:]
# Out:
# Hugo_Symbol                                                      CELF6
# Entrez_Gene_Id                                                 60677.0
# Center                                                               .
# NCBI_Build                                                      GRCh37
# Chromosome                                                          15
#                                            ...
# all_effects          CELF6,synonymous_variant,p.%3D,ENST00000567083...
# cDNA_position                                                      579
# n_depth                                                             17
# t_depth                                                             18
# Annotation_Status                                              SUCCESS
# Name: 0, Length: 114, dtype: object

# %%
raw_data_patient = pd.read_table("./data/data_clinical_patient.txt", sep="\t")
raw_data_patient.columns
# Out:
# Index(['#Patient Identifier', 'Subtype',
#        'TCGA PanCanAtlas Cancer Type Acronym', 'Other Patient ID',
#        'Diagnosis Age', 'Sex',
#        'Neoplasm Disease Stage American Joint Committee on Cancer Code',
#        'American Joint Committee on Cancer Publication Version Type',
#        'Last Communication Contact from Initial Pathologic Diagnosis Date',
#        'Birth from Initial Pathologic Diagnosis Date',
#        'Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value',
#        'Ethnicity Category', 'Form completion date',
#        'Neoadjuvant Therapy Type Administered Prior To Resection Text',
#        'ICD-10 Classification',
#        'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code',
#        'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code',
#        'Informed consent verified',
#        'New Neoplasm Event Post Initial Therapy Indicator',
#        'American Joint Committee on Cancer Metastasis Stage Code',
#        'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code',
#        'American Joint Committee on Cancer Tumor Stage Code',
#        'Person Neoplasm Cancer Status',
#        'Primary Lymph Node Presentation Assessment', 'Prior Diagnosis',
#        'Race Category', 'Radiation Therapy', 'Patient Weight',
#        'In PanCan Pathway Analysis', 'Overall Survival Status',
#        'Overall Survival (Months)', 'Disease-specific Survival status',
#        'Months of disease-specific survival', 'Disease Free Status',
#        'Disease Free (Months)', 'Progression Free Status',
#        'Progress Free Survival (Months)'],
#       dtype='object')

# %% [markdown]
# ## Clinical Patient

# %%
raw_data_sample = pd.read_table("./data/data_clinical_sample.txt", sep="\t")
raw_data_sample.head()
# Out:
#                           #Patient Identifier            Sample Identifier  \
# 0  #Identifier to uniquely specify a patient.  A unique sample identifier.
# 1                                     #STRING                       STRING
# 2                                          #1                            1
# 3                                  PATIENT_ID                    SAMPLE_ID
# 4                                TCGA-CS-4938              TCGA-CS-4938-01
#
#    Oncotree Code  Cancer Type  Cancer Type Detailed   Tumor Type  \
# 0  Oncotree Code  Cancer Type  Cancer Type Detailed   Tumor Type
# 1         STRING       STRING                STRING       STRING
# 2              1            1                     1            1
# 3  ONCOTREE_CODE  CANCER_TYPE  CANCER_TYPE_DETAILED   TUMOR_TYPE
# 4           DIFG       Glioma           Astrocytoma  Astrocytoma
#
#                            Neoplasm Histologic Grade  \
# 0  Numeric value to express the degree of abnorma...
# 1                                             STRING
# 2                                                  1
# 3                                              GRADE
# 4                                                 G2
#
#     Tissue Prospective Collection Indicator  \
# 0  Tissue prospective collection indicator.
# 1                                    STRING
# 2                                         1
# 3   TISSUE_PROSPECTIVE_COLLECTION_INDICATOR
# 4                                        No
#
#     Tissue Retrospective Collection Indicator  Tissue Source Site Code  \
# 0  Tissue retrospective collection indicator.  Tissue Source Site Code
# 1                                      STRING                   STRING
# 2                                           1                        1
# 3   TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR  TISSUE_SOURCE_SITE_CODE
# 4                                         Yes                       CS
#
#                          Tumor Disease Anatomic Site  Aneuploidy Score  \
# 0  Text term that describes the anatomic site of ...  Aneuploidy Score
# 1                                             STRING            NUMBER
# 2                                                  1                 1
# 3                                  TUMOR_TISSUE_SITE  ANEUPLOIDY_SCORE
# 4                                                CNS                 1
#
#                                          Sample Type  \
# 0  The type of sample (i.e., normal, primary, met...
# 1                                             STRING
# 2                                                  9
# 3                                        SAMPLE_TYPE
# 4                                            Primary
#
#                                     MSI MANTIS Score  \
# 0  MSI Score reported by MANTIS. The suggested th...
# 1                                             NUMBER
# 2                                                  9
# 3                                   MSI_SCORE_MANTIS
# 4                                              0.303
#
#                                      MSIsensor Score  Somatic Status  \
# 0  MSI Score reported by MSIsensor. The suggested...  Somatic Status
# 1                                             NUMBER          STRING
# 2                                                  9               1
# 3                                   MSI_SENSOR_SCORE  SOMATIC_STATUS
# 4                                                  0         Matched
#
#    TMB (nonsynonymous)                                 Tissue Source Site
# 0  TMB (nonsynonymous)  A Tissue Source Site collects samples (tissue,...
# 1               NUMBER                                             STRING
# 2                    1                                                  1
# 3    TMB_NONSYNONYMOUS                                 TISSUE_SOURCE_SITE
# 4          0.466666667                        Thomas Jefferson University

# %%
raw_data_sample.columns = raw_data_sample.iloc[3,:]
raw_data_sample = raw_data_sample.drop([0,1,2,3], axis = 0)

# %%
df_patient = raw_data_sample.reset_index().drop(["index"], axis = 1)
df_patient.head()
# Out:
# 3    PATIENT_ID        SAMPLE_ID ONCOTREE_CODE CANCER_TYPE  \
# 0  TCGA-CS-4938  TCGA-CS-4938-01          DIFG      Glioma
# 1  TCGA-CS-4941  TCGA-CS-4941-01          DIFG      Glioma
# 2  TCGA-CS-4942  TCGA-CS-4942-01          DIFG      Glioma
# 3  TCGA-CS-4943  TCGA-CS-4943-01          DIFG      Glioma
# 4  TCGA-CS-4944  TCGA-CS-4944-01          DIFG      Glioma
#
# 3 CANCER_TYPE_DETAILED   TUMOR_TYPE GRADE  \
# 0          Astrocytoma  Astrocytoma    G2
# 1          Astrocytoma  Astrocytoma    G3
# 2          Astrocytoma  Astrocytoma    G3
# 3          Astrocytoma  Astrocytoma    G3
# 4          Astrocytoma  Astrocytoma    G2
#
# 3 TISSUE_PROSPECTIVE_COLLECTION_INDICATOR  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
#
# 3 TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR TISSUE_SOURCE_SITE_CODE  \
# 0                                       Yes                      CS
# 1                                       Yes                      CS
# 2                                       Yes                      CS
# 3                                       Yes                      CS
# 4                                       Yes                      CS
#
# 3 TUMOR_TISSUE_SITE ANEUPLOIDY_SCORE SAMPLE_TYPE MSI_SCORE_MANTIS  \
# 0               CNS                1     Primary            0.303
# 1               CNS                7     Primary           0.2736
# 2               CNS                2     Primary            0.281
# 3               CNS                5     Primary           0.2751
# 4               CNS                1     Primary           0.2697
#
# 3 MSI_SENSOR_SCORE SOMATIC_STATUS TMB_NONSYNONYMOUS  \
# 0                0        Matched       0.466666667
# 1                0        Matched       1.466666667
# 2             0.02        Matched       0.866666667
# 3             0.25        Matched               0.8
# 4             0.04        Matched               0.7
#
# 3           TISSUE_SOURCE_SITE
# 0  Thomas Jefferson University
# 1  Thomas Jefferson University
# 2  Thomas Jefferson University
# 3  Thomas Jefferson University
# 4  Thomas Jefferson University

# %% [markdown]
# ## Creating anndata with sample as its obs:

# %%
df_sample_with_gene = df_clean_1.merge(df_patient, left_index=True, right_on = "SAMPLE_ID")

# %%
X = df_sample_with_gene.iloc[:,0:-17].copy()
X = X.set_index("PATIENT_ID")
obs = df_sample_with_gene.iloc[:,-18:].copy()
obs = obs.set_index("PATIENT_ID")
adata_sample = sc.AnnData(df_temp, obs = obs)

# %%
adata_sample.obs
# Out:
#                     SAMPLE_ID ONCOTREE_CODE CANCER_TYPE CANCER_TYPE_DETAILED  \
# PATIENT_ID
# TCGA-CS-4938  TCGA-CS-4938-01          DIFG      Glioma          Astrocytoma
# TCGA-CS-4941  TCGA-CS-4941-01          DIFG      Glioma          Astrocytoma
# TCGA-CS-4942  TCGA-CS-4942-01          DIFG      Glioma          Astrocytoma
# TCGA-CS-4943  TCGA-CS-4943-01          DIFG      Glioma          Astrocytoma
# TCGA-CS-4944  TCGA-CS-4944-01          DIFG      Glioma          Astrocytoma
# ...                       ...           ...         ...                  ...
# TCGA-WY-A85A  TCGA-WY-A85A-01          DIFG      Glioma          Astrocytoma
# TCGA-WY-A85B  TCGA-WY-A85B-01          DIFG      Glioma          Astrocytoma
# TCGA-WY-A85C  TCGA-WY-A85C-01          DIFG      Glioma          Astrocytoma
# TCGA-WY-A85D  TCGA-WY-A85D-01          OAST      Glioma     Oligoastrocytoma
# TCGA-WY-A85E  TCGA-WY-A85E-01          OAST      Glioma     Oligoastrocytoma
#
#                     TUMOR_TYPE GRADE TISSUE_PROSPECTIVE_COLLECTION_INDICATOR  \
# PATIENT_ID
# TCGA-CS-4938       Astrocytoma    G2                                      No
# TCGA-CS-4941       Astrocytoma    G3                                      No
# TCGA-CS-4942       Astrocytoma    G3                                      No
# TCGA-CS-4943       Astrocytoma    G3                                      No
# TCGA-CS-4944       Astrocytoma    G2                                      No
# ...                        ...   ...                                     ...
# TCGA-WY-A85A       Astrocytoma    G2                                      No
# TCGA-WY-A85B       Astrocytoma    G2                                      No
# TCGA-WY-A85C       Astrocytoma    G2                                      No
# TCGA-WY-A85D  Oligoastrocytoma    G2                                      No
# TCGA-WY-A85E  Oligoastrocytoma    G2                                      No
#
#              TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR  \
# PATIENT_ID
# TCGA-CS-4938                                       Yes
# TCGA-CS-4941                                       Yes
# TCGA-CS-4942                                       Yes
# TCGA-CS-4943                                       Yes
# TCGA-CS-4944                                       Yes
# ...                                                ...
# TCGA-WY-A85A                                       Yes
# TCGA-WY-A85B                                       Yes
# TCGA-WY-A85C                                       Yes
# TCGA-WY-A85D                                       Yes
# TCGA-WY-A85E                                       Yes
#
#              TISSUE_SOURCE_SITE_CODE TUMOR_TISSUE_SITE ANEUPLOIDY_SCORE  \
# PATIENT_ID
# TCGA-CS-4938                      CS               CNS                1
# TCGA-CS-4941                      CS               CNS                7
# TCGA-CS-4942                      CS               CNS                2
# TCGA-CS-4943                      CS               CNS                5
# TCGA-CS-4944                      CS               CNS                1
# ...                              ...               ...              ...
# TCGA-WY-A85A                      WY               CNS                1
# TCGA-WY-A85B                      WY               CNS                0
# TCGA-WY-A85C                      WY               CNS                0
# TCGA-WY-A85D                      WY               CNS                0
# TCGA-WY-A85E                      WY               CNS                5
#
#              SAMPLE_TYPE MSI_SCORE_MANTIS MSI_SENSOR_SCORE SOMATIC_STATUS  \
# PATIENT_ID
# TCGA-CS-4938     Primary            0.303                0        Matched
# TCGA-CS-4941     Primary           0.2736                0        Matched
# TCGA-CS-4942     Primary            0.281             0.02        Matched
# TCGA-CS-4943     Primary           0.2751             0.25        Matched
# TCGA-CS-4944     Primary           0.2697             0.04        Matched
# ...                  ...              ...              ...            ...
# TCGA-WY-A85A     Primary           0.3252             0.02        Matched
# TCGA-WY-A85B     Primary           0.3309             0.03        Matched
# TCGA-WY-A85C     Primary           0.3184             0.04        Matched
# TCGA-WY-A85D     Primary           0.3142                0        Matched
# TCGA-WY-A85E     Primary           0.3171                0        Matched
#
#              TMB_NONSYNONYMOUS           TISSUE_SOURCE_SITE
# PATIENT_ID
# TCGA-CS-4938       0.466666667  Thomas Jefferson University
# TCGA-CS-4941       1.466666667  Thomas Jefferson University
# TCGA-CS-4942       0.866666667  Thomas Jefferson University
# TCGA-CS-4943               0.8  Thomas Jefferson University
# TCGA-CS-4944               0.7  Thomas Jefferson University
# ...                        ...                          ...
# TCGA-WY-A85A       0.466666667                Johns Hopkins
# TCGA-WY-A85B       0.433333333                Johns Hopkins
# TCGA-WY-A85C               0.9                Johns Hopkins
# TCGA-WY-A85D       1.033333333                Johns Hopkins
# TCGA-WY-A85E       1.933333333                Johns Hopkins
#
# [514 rows x 17 columns]

# %%
sc.tl.pca(adata_sample, svd_solver = "arpack")
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:00)

# %%
sc.pl.pca(adata_sample, color = ["TUMOR_TYPE"])

# %%
sc.pl.pca(adata_sample, color = ["GRADE"])

# %%
sc.pp.neighbors(adata_sample, n_neighbors=3)
sc.tl.umap(adata_sample, min_dist=0.3)
sc.pl.umap(adata_sample, color = ["GRADE"])
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
sc.pp.neighbors(adata_sample, n_neighbors=5)
sc.tl.umap(adata_sample, min_dist=0.3)
sc.pl.umap(adata_sample, color = ["GRADE"])
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
sc.pl.umap(adata_sample, color = ["TUMOR_TYPE"])
