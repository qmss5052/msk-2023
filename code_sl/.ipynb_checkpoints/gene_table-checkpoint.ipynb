# %%
import pandas as pd 
df = pd.read_table("../supplement_data/gene_table.tsv")

# %%
df
# Out:
#        NCBI GeneID    Symbol  \
# 0             7157      TP53
# 1             1956      EGFR
# 2             7124       TNF
# 3              348      APOE
# 4             7422     VEGFA
# ...            ...       ...
# 72841         9831    ZNF623
# 72842         9906  SLC35E2A
# 72843         9959   USP12P1
# 72844         9964    MYCLP3
# 72845         9995    ELK2BP
#
#                                             Description Taxonomic Name  \
# 0                                     tumor protein p53   Homo sapiens
# 1                      epidermal growth factor receptor   Homo sapiens
# 2                                 tumor necrosis factor   Homo sapiens
# 3                                      apolipoprotein E   Homo sapiens
# 4                  vascular endothelial growth factor A   Homo sapiens
# ...                                                 ...            ...
# 72841                           zinc finger protein 623   Homo sapiens
# ...
